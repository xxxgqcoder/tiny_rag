# %% [markdown]
# # Debug vector db

# %%
import os
import json

import config

from rag.db import get_vector_db, get_rational_db


file_path = '/var/share/tiny_rag_files/Chain-of-Thought Prompting Elicits Reasoning in Large Language Models (dragged).pdf'

file_name = os.path.basename(file_path)

# %% [markdown]
# # SQL db

# %%
sql_db = get_rational_db()

ret = sql_db.get_document(name=file_name)
print(json.dumps(ret, indent=4))

# %% [markdown]
# ## Get all documents

# %%
all_documents = sql_db.get_all_documents()
len(all_documents)
